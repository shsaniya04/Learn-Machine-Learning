# %% [markdown]
# <a href="https://colab.research.google.com/github/shsaniya04/Learn-Machine-Learning/blob/main/01_Read_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import** **Library**

# %%
import pandas as pd

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/hotel_bookings.csv')
# Out:
#                hotel is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel          no        342               2015
# 1       Resort Hotel          no        737               2015
# 2       Resort Hotel          no          7               2015
# 3       Resort Hotel          no         13               2015
# 4       Resort Hotel          no         14               2015
# ...              ...         ...        ...                ...
# 119385    City Hotel          no         23               2017
# 119386    City Hotel          no        102               2017
# 119387    City Hotel          no         34               2017
# 119388    City Hotel          no        109               2017
# 119389    City Hotel          no        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/movie_titles_metadata.tsv')
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/movie_titles_metadata.tsv',sep = '\t')
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/movie_titles_metadata.tsv',sep = '\t',names = ['sno','name','relese_year','rating','votes','genres'])
# Out:
#       sno                        name relese_year  rating     votes  \
# 0      m0  10 things i hate about you        1999     6.9   62847.0
# 1      m1  1492: conquest of paradise        1992     6.2   10421.0
# 2      m2                  15 minutes        2001     6.1   25854.0
# 3      m3       2001: a space odyssey        1968     8.4  163227.0
# 4      m4                     48 hrs.        1982     6.9   22289.0
# ..    ...                         ...         ...     ...       ...
# 612  m612                    watchmen        2009     7.8  135229.0
# 613  m613                         xxx        2002     5.6   53505.0
# 614  m614                       x-men        2000     7.4  122149.0
# 615  m615          young frankenstein        1974     8.0   57618.0
# 616  m616                   zulu dawn        1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', index_col = 'enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', header = 1)
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      29725   city_40  0.776  Male   No relevent experience
# 1      11561   city_21  0.624   NaN   No relevent experience
# 2      33241  city_115  0.789   NaN   No relevent experience
# 3        666  city_162  0.767  Male  Has relevent experience
# 4      21651  city_176  0.764   NaN  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19152   7386  city_173  0.878  Male   No relevent experience
# 19153  31398  city_103  0.920  Male  Has relevent experience
# 19154  24576  city_103  0.920  Male  Has relevent experience
# 19155   5756   city_65  0.802  Male  Has relevent experience
# 19156  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0         no_enrollment        Graduate             STEM   15      50-99
# 1      Full time course        Graduate             STEM    5        NaN
# ...

# %%
# pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', usecols = ['gender'], squeeze = True)
# Remove the 'squeeze' argument. This will return a DataFrame instead of a Series.
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', usecols=['gender'])

# If you need a Series, you can convert the 'gender' column after reading the DataFrame.
gender_series = df['gender']

# %%
gender_series
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', usecols=['enrollee_id','gender','education_level'])
df
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', skiprows = [0,1])
df
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1      33241  city_115               0.789   NaN   No relevent experience
# 2        666  city_162               0.767  Male  Has relevent experience
# 3      21651  city_176               0.764   NaN  Has relevent experience
# 4      28806  city_160               0.920  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19151   7386  city_173               0.878  Male   No relevent experience
# 19152  31398  city_103               0.920  Male  Has relevent experience
# 19153  24576  city_103               0.920  Male  Has relevent experience
# 19154   5756   city_65               0.802  Male  Has relevent experience
# 19155  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', nrows = 10)
df
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
# 5        21651  city_176                   0.764    NaN
# 6        28806  city_160                   0.920   Male
# 7          402   city_46                   0.762   Male
# 8        27107  city_103                   0.920   Male
# 9          699  city_103                   0.920    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-9e20fbde1822> in <cell line: 0>()
# ----> 1 pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/zomato.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/zomato.csv', encoding = 'latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/zomato.csv', address = ';',encoding = 'latin-1')

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', dtype = {'target' : int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/IPL Matches 2008-2020.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv').head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv',na_values =['Male']).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920    NaN
# 1        29725   city_40                   0.776    NaN
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
dfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/aug_train.csv', chunksize = 5000)

# %%
for chunk in dfs:
  print(chunk)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 10000        23427   city_24                   0.698     NaN
# 10001        17605   city_50                   0.896     NaN
# 10002        20912   city_73                   0.754     NaN
# 10003        13948  city_114                   0.926    Male
# 10004        15205  city_160                   0.920    Male
# ...            ...       ...                     ...     ...
# 14995         1305  city_103                   0.920    Male
# 14996        10310  city_103                   0.920  Female
# 14997        10689   city_21                   0.624     NaN
# 14998          605   city_16                   0.910    Male
# 14999        14587   city_16                   0.910    Male
#
#            relevent_experience enrolled_university education_level  \
# 10000   No relevent experience                 NaN     High School
# 10001   No relevent experience       no_enrollment        Graduate
# ...
