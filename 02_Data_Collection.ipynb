# %% [markdown]
# <a href="https://colab.research.google.com/github/shsaniya04/Learn-Machine-Learning/blob/main/02_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
# response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5bc643f664c8c66e7edce11b77c7214e&language=en-US&page=1')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Learning Machine Learning/imdb_top_rated_movies.csv')

# %%
# pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'release_date', 'overview', 'popularity',
#        'vote_average'],
#       dtype='object')

# %%
df = df[['id','title','release_date','overview','popularity','vote_average']]

# %%
df.head()
# Out:
#       id                        title release_date  \
# 0    238                The Godfather   1972-03-14
# 1    278     The Shawshank Redemption   1994-09-23
# 2    240        The Godfather Part II   1974-12-20
# 3    424             Schindler's List   1993-12-15
# 4  19404  Dilwale Dulhania Le Jayenge   1995-10-20
#
#                                             overview  popularity  vote_average
# 0  Spanning the years 1945 to 1955, a chronicle o...     146.546         8.709
# 1  Framed in the 1940s for the double murder of h...     127.603         8.705
# 2  In the continuing saga of the Corleone crime f...      77.946         8.590
# 3  The true story of how businessman Oskar Schind...      86.658         8.571
# 4  Raj is a rich, carefree, happy-go-lucky second...      50.500         8.546
